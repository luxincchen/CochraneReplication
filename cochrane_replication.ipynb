# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

from cochrane_replication import (
    load_shiller,
    load_fama_french,
    build_table1,
    build_figure1,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install xlrd

# %%
SHILLER_PATH = "shiller_data.xls"
FF_PATH = "F-F_Research_Data_Factors.csv"

start_year = 1965
end_year = 2023

shiller_ann = load_shiller(SHILLER_PATH, start_year, end_year)
ff_ann      = load_fama_french(FF_PATH, start_year, end_year)

data = shiller_ann.join(ff_ann, how="inner")
data.head()
# Out:
#             dp  dp_level        div      Rx
# year
# 1965 -3.518218  0.029652  27.834496  0.1007
# 1966 -3.344203  0.035288  28.387528 -0.1324
# 1967 -3.485446  0.030640  28.030105  0.2202
# 1968 -3.546467  0.028826  28.141782  0.0908
# 1969 -3.361496  0.034683  27.276416 -0.1692

# %%
table1 = build_table1(data, horizons=(1,2,3,5))
table1.round(4)
# Out:
#    k     b_x  t(b)_x    R2_x     b_y  t(b)_y    R2_y
# 0  1  0.0564  1.0924  0.0176 -0.0391 -2.3791  0.0739
# 1  2  0.1088  1.4008  0.0339 -0.0300 -1.6203  0.0589
# 2  3  0.0993  0.9216  0.0215 -0.0253 -1.3107  0.0540
# 3  5  0.1620  1.1778  0.0344 -0.0277 -1.8207  0.1076

# %%
#Table 1 (Cochrane, 2007) – Predictive regressions of excess returns and dividend growth on log(D/P)

#This table reports Cochrane-style forecasting regressions for horizons k = 1, 2, 3, 5 using the 1965–2023 sample. 
#The left panel shows excess return predictability; the right panel shows dividend growth regressions.

# %%
build_figure1(data, k=7)

# %%
# Figure 1 (Cochrane, 2011) - 4 x D/P and subsequent 7-year annualized returns

#This figure plots four times the dividned-price ratio with the annualized 7-year foreard return.
